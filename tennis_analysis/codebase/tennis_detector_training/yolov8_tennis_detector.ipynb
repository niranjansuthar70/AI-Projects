# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
yaml_path="/content/drive/MyDrive/Learning_AI_dataset/Deep_Learning_dataset/object_detection/tennis_ball_detection/tennis_roboflow_dataset/data.yaml"

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model=yolov8x.pt data={yaml_path} epochs=10 imgsz=640
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 304MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv /content/runs "/content/drive/Othercomputers/My Computer/gdrive/Learning_AI/projects/tennis_analysis/codebase/tennis_detector_training"

# %%
import torch
from ultralytics import YOLO
print(torch.cuda.is_available())

model = YOLO('/content/drive/Othercomputers/My Computer/gdrive/Learning_AI/projects/tennis_analysis/codebase/tennis_detector_training/runs/detect/train/weights/best.pt')

result = model.track('/content/drive/Othercomputers/My Computer/gdrive/Learning_AI/projects/tennis_analysis/sample_input_data/input_video.mp4',conf=0.2, save=True)
# print(result)
# print("boxes:")
# for box in result[0].boxes:
#     print(box)
# Out:
# True
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 6.1s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...
